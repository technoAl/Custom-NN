# %%
import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.rand(N)
y = np.random.rand(N)

plt.scatter(x, y)
plt.show()

# %%
xs = []
ys = []
first = True

with open("test420.in", "r") as a_file:
  for line in a_file:
    if not first:
        stripped_line = line.strip()
        xs.append(stripped_line.split(" ")[0])
        ys.append(stripped_line.split(" ")[1])
    first = False

# %%
xss = np.asfarray(xs)
yss = np.asfarray(ys)

# %%
plt.scatter(yss, 10-xss)
plt.show()
